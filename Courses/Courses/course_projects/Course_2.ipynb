# %% [markdown]
# WALDO RIVIER 02.10.2018 Exercices du module 2 Applied Data Science: Machine Learning
#
# Notes concerning data manipulation, especially "normalization" of the ingredients'list.
# Because aliments and ingredients are stored in differents language, I tried to translate the laters in english using googletrans API for python.
#
# It works pretty well until google made an update of this interface. So I decide to stop using this interface.
# Fortunately, the result of the "most used ingredients" did'nt change.
#
# Notes concerning database exercice, especially the definition of a primary key.
# The idea was :
# - store a df to sqlite database
# - alter table definition to set a primary key.
#
# The second part could not be done, because alter table command isn't support by sqlite.
#
# Following step must be done :
# - stores normalized df to database
# - extract tables definition
# - add a primary key 'product_name' to table aliment
# - create a database with this new definition
# - stores normalized df again to this database with option 'append'
#
#
# I expect the book documented enough to allow a slight reading.

# %%
import os
from pathlib import PureWindowsPath
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import random
# import googletrans as translator
from pandas.tseries.offsets import *
import calendar

# %% [markdown]
# répertoire de travail

# %%
data_dir = working_dir = PureWindowsPath(os.getcwd())
data_result_name = 'result.csv'

# %%
pd.set_option('display.max_columns', 30)

# %% [markdown]
#  Class utilities
# - translation
# - outliers
# - words dictionnary

# %%
class utilities:
    #-------------------------------------------------------------------------
    # retourne la liste des noms de colonne d'un type 
    #-------------------------------------------------------------------------
    def select_columns(df, type):
        columns = df.dtypes[df.dtypes.apply(lambda x : x == type)].index.tolist()
        return columns

    #-------------------------------------------------------------------------
    # identifier et gérer les valeurs extrêmes 
    # on considère le seuil de 1% pour déterminer les valeurs extrêmes; ce seuil
    # determine (sous l'hypothèse de normalité de la distribution) toutes les valeurs 
    # x | x > abs(mean - 3 * std) 
    #-------------------------------------------------------------------------
    def remove_outliers(df, col_name):

        def reject(ser : pd.Series):
            mean = ser.mean() 
            std  = 3 * ser.std()
  
            def f(x):
                reject = False

                if np.abs(x - mean) > std : 
                    reject = True
                return reject
    
            return f

        ser_col = df.loc[:,col_name]
        f_reject = reject(ser_col)
        df = df.loc[~ser_col.apply(f_reject)]

        return df

    #-------------------------------------------------------------------------
    # translate a word (one at a time) in english with googletrans
    #-------------------------------------------------------------------------
    def translate_word():

        trans = translator.Translator()

        def f(x : str):
            try :
                if not x.isalpha():
                    return x

                elif x == "SEL":
                    return "SALT"

                else :
                    # t = trans.translate(x)
                    # return t.text

                    return x

            except ValueError:
                print ("erreur dans la traduction", x)
        
        return f

    #-------------------------------------------------------------------------
    # fill a dictionnary with all word and count occurences
    # dict_words : dictionnary filled
    #-------------------------------------------------------------------------
    def build_word_dictionary(dict_words):
        assert type(dict_words) is dict
   
        def f(x : str):
            try :
                ser_words = pd.read_json(x, typ="records")
                for item in ser_words.iteritems():
                    word = item[1].upper()

                    if (dict_words.get(word) is not None) :
                        dict_words[word] += 1
                    else :
                        dict_words[word] = 1
        
            except Exception:   
                print ("build dictionary error")

        return f

# %% [markdown]
# saves / loads a df to / from database

# %%
def helper_store_df_to_db(df, db_name, table_name) :

    db_file = PureWindowsPath(data_dir.joinpath(db_name + ".db" ))
    db = sqlite3.connect(db_file.as_posix())

    df.to_sql(table_name, db, chunksize=2000, if_exists='replace')
    db.close()

def helper_load_df_from_db(db_name, table_name) :

    db_file = PureWindowsPath(data_dir.joinpath(db_name + ".db"))
    db = sqlite3.connect(db_file.as_posix())

    df = pd.read_sql_query("select * from " + table_name, con=db)
    db.close()

    return df

def helper_store_csv_to_db(data_file, db_name, table_name) :
 
    db_file = PureWindowsPath(data_dir.joinpath(db_name + ".db" ))
    db = sqlite3.connect(db_file.as_posix())
    
    for chunk in pd.read_csv(data_file, chunksize=2000):
        chunk.to_sql(name=table_name, con=db, if_exists="append", index=False)  

    db.close()

# %% [markdown]
# original file "en.openfoodfacts.org.products.tsv" est chargé dans une base
# will be loaded and stored in a database name 'food.db' table name  'data'

# %%
def read_raw_data():

    data_file = PureWindowsPath(data_dir.joinpath('en.openfoodfacts.org.products.tsv'))
    helper_store_csv_to_db(data_file, "food", "data")

# %% [markdown]
# export to csv file all the columns containing null values

# %%
def export_null_columns(df, data_file) : 
   
    ser_column_null = df.isnull().sum()
    ser_column_null.sort_index(inplace=True)
    ser_column_null.to_csv(data_file)

# %% [markdown]
# analyze columns : apply series of threshes (by step 10000) on the df and mesures the number
# of remaining columns.
#
# plot the result

# %%
def analyze_columns(df_food_study) :

    df = df_food_study.copy()
    
    null_values_max = df.isnull().sum().max()
    if null_values_max > 0:
        threshes = np.arange(0, null_values_max, 10000)
     
        rows = []

        def select_columns(df, thresh):
            df = df.dropna(thresh=thresh, axis=1)
        
            dict = {'_thresh' : 0, '_shape' : 0}
            dict['_thresh'] = thresh
            dict['_shape'] = df.shape[1]
    
            rows.append(dict)
        
        for thresh in threshes :
            select_columns (df, thresh)
    
        # build a dataframe based on dict of rows
        df_result = pd.DataFrame(rows)  
            
        df_result.to_csv(data_dir.joinpath(data_result_name))
 
        fig, ax = plt.subplots(nrows=1, ncols=1)
        fig.suptitle("numbers of remaining columns in terms of thresh for a df of shape (" +  
                        str(df_food_study.shape[0]) + "," + str(df_food_study.shape[1]) + ")")
        
        x_pos = np.arange(len(df_result))
        ax.bar(x_pos, df_result._shape, align='center', color='green')
        ax.set_xticks(x_pos)
        ax.set_xticklabels(df_result._thresh, rotation=45)

        ax.set_ylabel("remaining columns")
        ax.set_xlabel("thresh")

        plt.show()

# %% [markdown]
#  ETUDE A : analyze meta-data and clean-up

# %% [markdown]
# First step of data cleaning :
# columns will be reduced to a level that minimize the lost of relevant
# data
#
# resulting df will be store in database

# %%
df_food = helper_load_df_from_db("food", "data")

# %%
# eliminate all columns with all null values
# df will be reduced from 163 columns to 147

df_food.dropna(axis=1, how="all", inplace=True)

# %%
# check for duplicated 

if df_food.drop_duplicates().shape == df_food.shape:
    print ("df doesn't contain duplicated data")
# Out:
# df doesn't contain duplicated data

# %%
analyze_columns(df_food)

# %% [markdown]
# From the graphic above (and further analysis) we can conclude that a thresh of ~ 50% of total entries determines an optimum. That is, from this level, the cost of adding a column brings more null values that not null values.

# %%
# a thesh level of 150'000 (all columns with number of null values > 150'000 will bw ewmoved), defines a selection of 36 columns 
# which encompass all the necessary columns for our investigations

df_food_cl = df_food.dropna(thresh=150000, axis=1)

# %%
df_food_cl.head()
# Out:
#       code                                                url  \
# 0   3087.0  http://world-en.openfoodfacts.org/product/0000...
# 1   4530.0  http://world-en.openfoodfacts.org/product/0000...
# 2   4559.0  http://world-en.openfoodfacts.org/product/0000...
# 3  16087.0  http://world-en.openfoodfacts.org/product/0000...
# 4  16094.0  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#             brands      brands_tags countries    countries_tags  \
# 0  Ferme t'y R'nao  ferme-t-y-r-nao     en:FR         en:france
# 1             None             None        US  en:united-states
# 2   Torn & Glasser     torn-glasser        US  en:united-states
# 3        Grizzlies        grizzlies        US  en:united-states
# 4   Bob's Red Mill   bob-s-red-mill        US  en:united-states
#
#     countries_en                                   ingredients_text  \
# 0         France                                               None
# 1  United States  Bananas, vegetable oil (coconut oil, corn oil ...
# 2  United States  Peanuts, wheat flour, sugar, rice flour, tapio...
# 3  United States  Organic hazelnuts, organic cashews, organic wa...
# 4  United States                                    Organic polenta
#
#       serving_size           ...             nutrition_grade_fr  \
# 0             None           ...                           None
# 1     28 g (1 ONZ)           ...                              d
# 2  28 g (0.25 cup)           ...                              b
# 3  28 g (0.25 cup)           ...                              d
# 4  35 g (0.25 cup)           ...                           None
#
#                                               states  \
# 0  en:to-be-completed, en:nutrition-facts-to-be-c...
# 1  en:to-be-completed, en:nutrition-facts-complet...
# 2  en:to-be-completed, en:nutrition-facts-complet...
# 3  en:to-be-completed, en:nutrition-facts-complet...
# 4  en:to-be-completed, en:nutrition-facts-complet...
#
#                                          states_tags  \
# 0  en:to-be-completed,en:nutrition-facts-to-be-co...
# 1  en:to-be-completed,en:nutrition-facts-complete...
# 2  en:to-be-completed,en:nutrition-facts-complete...
# 3  en:to-be-completed,en:nutrition-facts-complete...
# 4  en:to-be-completed,en:nutrition-facts-complete...
#
#                                            states_en  energy_100g  fat_100g  \
# 0  To be completed,Nutrition facts to be complete...          NaN       NaN
# 1  To be completed,Nutrition facts completed,Ingr...       2243.0     28.57
# 2  To be completed,Nutrition facts completed,Ingr...       1941.0     17.86
# 3  To be completed,Nutrition facts completed,Ingr...       2540.0     57.14
# 4  To be completed,Nutrition facts completed,Ingr...       1552.0      1.43
#
#   saturated-fat_100g carbohydrates_100g sugars_100g fiber_100g  proteins_100g  \
# 0                NaN                NaN         NaN        NaN            NaN
# 1              28.57              64.29       14.29        3.6           3.57
# 2               0.00              60.71       17.86        7.1          17.86
# 3               5.36              17.86        3.57        7.1          17.86
# 4                NaN              77.14         NaN        5.7           8.57
#
#    salt_100g  sodium_100g  nutrition-score-fr_100g  nutrition-score-uk_100g
# 0        NaN          NaN                      NaN                      NaN
# 1    0.00000        0.000                     14.0                     14.0
# 2    0.63500        0.250                      0.0                      0.0
# 3    1.22428        0.482                     12.0                     12.0
# 4        NaN          NaN                      NaN                      NaN
#
# [5 rows x 36 columns]

# %%
# eliminates columns containing word 'completed' which seems not to be relevant
# example : counting  occurrences  for column 'tags' 

df_food_cl.states_tags.where(lambda x : x.str.contains("completed")).count()
# Out:
# 355975

# %%
# eliminates columns whose name contains 'states' or 'tags

df_food_cl = df_food_cl.drop([col for col in df_food_cl.columns if "states" in col], axis=1)
df_food_cl = df_food_cl.drop([col for col in df_food_cl.columns if "tags" in col], axis=1)

# %%
df_food_cl.shape
# Out:
# (356027, 30)

# %%
df_food_cl.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name', 'brands',
#        'countries', 'countries_en', 'ingredients_text', 'serving_size',
#        'additives_n', 'additives', 'additives_en',
#        'ingredients_from_palm_oil_n',
#        'ingredients_that_may_be_from_palm_oil_n', 'nutrition_grade_fr',
#        'energy_100g', 'fat_100g', 'saturated-fat_100g', 'carbohydrates_100g',
#        'sugars_100g', 'fiber_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g', 'nutrition-score-fr_100g', 'nutrition-score-uk_100g'],
#       dtype='object')

# %%
# stores resulting df in database

helper_store_df_to_db(df_food_cl, "df_food_cl", "df_food_cl")

# %% [markdown]
# Second step of data cleaning
#
# The dataset based on that previously cleaned (which as been reduced to 30 columns)
#
# Mainly eliminates all null values, duplicated and numerical outliers
#
# dataset is sorted by 'last_modified_datetime' descending order in order to keep this datetime when duplicated rows will be removed.

# %%
def setup_db_study():

    df_food_study = helper_load_df_from_db("df_food_cl", "df_food_cl")
                  
    # eliminates null values
    df_food_study.dropna(inplace=True)

    # set an index
    df_food_study.set_index(['product_name'], inplace=True)
    df_food_study.sort_index(inplace=True)
    df_food_study.sort_values(by='last_modified_datetime', ascending = False, inplace=True)

    # index will be exported as csv to inspect duplicated entries
    df_food_study.index.to_series().to_csv(data_dir.joinpath(data_result_name))

    # list of all duplicated entries in the index
    df_food_study.loc[df_food_study.index.duplicated(),:]

    # remove all duplicated entries with the magical ~
    df_food_study = df_food_study.loc[~df_food_study.index.duplicated(),:]

    # eliminates duplicates
    df_food_study.drop_duplicates(inplace=True)

    # eliminates all outliers among numerical columns
    for col_name in utilities.select_columns(df_food_study, float):
        df_food_study = utilities.remove_outliers(df_food_study, col_name)
    
    # stores the resulting cleaned df to database
    helper_store_df_to_db(df_food_study, "df_food_study_1", "df_food_study_2")

# %%
setup_db_study()

# %% [markdown]
# ETUDE B : nutrient repartition
#
# sub functions

# %% [markdown]
# A balanced aliment is defined as follow :
#
# aliments which repartition approximate a balanced alimentation that is:
# 65% glucides, 25% proteins, 10% fats
#
# compute the distance between each aliment repartition and reference's aliment
# repartition define in df_reference_value
#
# return df with added repartition_score colum

# %%
def compute_repartition_score(df_food_study, col_macro_nutrients, df_reference_value):

    col_repartition_score = 'repartition_score'

    df = df_food_study.copy()
    df = df.loc[:,col_macro_nutrients]

    # calculate distance
    df = df.sub(df_reference_value.loc['repartition'], axis=1)
    df = np.power(df, 2)
    df[col_repartition_score] = np.power(df.sum(axis=1), 0.5)

    df = df_food_study.merge(df, left_index=True, right_index=True)

    # sort  
    df.sort_values(by = [col_repartition_score], inplace=True)
        
    return df

# %% [markdown]
# checks that energetic value announced in the data is comform to that which
# is recalculated in this function
#
# aliments whose energetic value seems inconsistent will be removed
#
# return df containing calories contained in each aliment's macronutrient

# %%
def check_energy_tot(df_food_study, col_macro_nutrients, df_reference_value):

    col_delta_energy = 'delta_energy'

    col_for_check = col_macro_nutrients.copy()
    col_for_check.append('energy_100g')
        
    df = df_food_study.copy()
    df = df.loc[:, col_for_check]
    df_reference_value = df_reference_value.reindex(col_for_check, axis=1).fillna(1)

    # multiply macronutrients quantities with correponding calories / gramm
    df = df.mul(df_reference_value.loc['energy_g'], axis=1)
    
    # conversion to joules
    df.iloc[:, 0:3] = df.iloc[:, 0:3] * 4.18

    # calculate delta energy compared to annouced value
    ser_energy_tot = df.loc[:, 'energy_100g']
    df[col_delta_energy] = (df.iloc[:, 0:3].sum(axis=1) - ser_energy_tot) / ser_energy_tot
        
    # retains only aliments which delta lies below 5% (in absolute value)
    df = df[df[col_delta_energy].between(-0.05, 0.05)]
 
    return df

# %% [markdown]
# for each aliment, compute the percentage of calories provided from
# each macronutrients
#
# return a df with ratio added columns

# %%
def compute_nutrient_breakdown_ratio(df_food_study, col_macro_nutrients, df_reference_value):
    
    df = check_energy_tot(df_food_study, col_macro_nutrients, df_reference_value)
        
    df['ratio_cal_fat'] = df.fat_100g / df.energy_100g
    df['ratio_cal_carbohydrates'] = df.carbohydrates_100g / df.energy_100g
    df['ratio_cal_proteins'] = df.proteins_100g / df.energy_100g
     
    return df

# %% [markdown]
# ETUDE B : plot the results

# %%
def plot_nutrient_breakdown_ratio(df_food_study, macro_nutrients):

    titles = pd.Series(macro_nutrients).apply(lambda x : str.upper(x)).tolist()
    col_ratios = pd.Series(macro_nutrients).apply(lambda x : "ratio_cal_" + x).tolist()
    labels = pd.Series(macro_nutrients).apply( lambda x : "Calories percentage of " + x)
    
    colors = ['red', 'blue', 'green']

    fig, axes = plt.subplots(nrows=3, ncols=1, sharey=False)
    fig.suptitle("Proportion of calories from macronutrients " 
                 + "(10 aliments from a sample of size " + str(df_food_study.shape[0]) + ")")
  
    for ratio in col_ratios : 
        i_ratio = col_ratios.index(ratio)

        df = df_food_study.copy()

        # the (few) values greater than 1 will be removed
        df = df[df.loc[:, ratio] <=1]
        df.sort_values(by=ratio, ascending=False, inplace=True)  
        df = df.loc[:, ratio]
        df = df.iloc[:10,]

        y_pos = np.arange(len(df))

        axes[i_ratio].axes.barh(y_pos, df * 100, align='center', color=colors[i_ratio])
        axes[i_ratio].axes.set_yticks(y_pos)

        # limits product name to 30 lexical characters
        axes[i_ratio].axes.set_yticklabels(df.index.str[0:30].tolist(), minor=False)
        axes[i_ratio].axes.invert_yaxis() 

        axes[i_ratio].set_xlabel(labels[i_ratio])
        axes[i_ratio].set_title(titles[i_ratio])
  
    # fig.tight_layout()
    plt.show()

def plot_nutrient_repartition_score(df_food_study):

    col_repartition_score = 'repartition_score'

    fig, ax = plt.subplots(nrows=1, ncols=1)
    fig.suptitle("The " + str(df_food_study.shape[0]) + " more balanced aliments according definition")
  
    df = df_food_study.loc[:,col_repartition_score]
    df = df.iloc[:20,]

    y_pos = np.arange(len(df))
    ax.barh(y_pos, df, align='center', color='green')
    ax.set_yticks(y_pos)

    # limits product name to 30 lexical characters
    ax.set_yticklabels(df.index.str[0:30].tolist())
    ax.invert_yaxis() 

    ax.set_xlabel("Score (distance to aliment's reference repartition)")
    
    # fig.tight_layout()
    plt.show()

# %% [markdown]
# ETUDE B : nutrient repartition
#
# main function

# %%
macro_nutrients = ['fat', 'carbohydrates', 'proteins'] 
col_macro_nutrients = pd.Series(macro_nutrients).apply(lambda x : x + "_100g").tolist()

# index repartion contains the "balanced" ratio (fat, carbohydrates, proteins) for an healthy alimentation !
df_reference_value = pd.DataFrame(data = [(15,60,25), (9,4,4)], 
                                  columns = col_macro_nutrients,
                                  index = ['repartition', 'energy_g'])

# %%
df_reference_value
# Out:
#              fat_100g  carbohydrates_100g  proteins_100g
# repartition        15                  60             25
# energy_g            9                   4              4

# %%
# loads definitive cleaned data from database

df_food_study = helper_load_df_from_db("df_food_study_1", "df_food_study_2")
df_food_study.set_index(['product_name'], inplace=True)
df_food_study.sort_index(inplace=True)

# %%
df_food_study.shape
# Out:
# (62812, 30)

# %%
df_food_study.columns
# Out:
# Index(['index', 'code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'brands', 'countries',
#        'countries_en', 'ingredients_text', 'serving_size', 'additives_n',
#        'additives', 'additives_en', 'ingredients_from_palm_oil_n',
#        'ingredients_that_may_be_from_palm_oil_n', 'nutrition_grade_fr',
#        'energy_100g', 'fat_100g', 'saturated-fat_100g', 'carbohydrates_100g',
#        'sugars_100g', 'fiber_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g', 'nutrition-score-fr_100g', 'nutrition-score-uk_100g'],
#       dtype='object')

# %%
df_food_study.head()
# Out:
#                                            index          code  \
# product_name
#  Beeren schokoliert                       287758  4.104420e+12
#  Biscuit Tablette Chocolat au Lait bio    219547  3.256221e+12
#  Calamars à la Romaine surgelés           220479  3.256224e+12
#  Crèmes brûlées à la vanille              230648  3.270160e+12
#  Olives espagnoles à la pâte de poivrons  185657  2.208303e+07
#
#                                                                                         url  \
# product_name
#  Beeren schokoliert                       http://world-en.openfoodfacts.org/product/4104...
#  Biscuit Tablette Chocolat au Lait bio    http://world-en.openfoodfacts.org/product/3256...
#  Calamars à la Romaine surgelés           http://world-en.openfoodfacts.org/product/3256...
#  Crèmes brûlées à la vanille              http://world-en.openfoodfacts.org/product/3270...
#  Olives espagnoles à la pâte de poivrons  http://world-en.openfoodfacts.org/product/2208...
#
#                                                              creator  \
# product_name
#  Beeren schokoliert                                        twoflower
#  Biscuit Tablette Chocolat au Lait bio    openfoodfacts-contributors
#  Calamars à la Romaine surgelés                             cestki13
#  Crèmes brûlées à la vanille                                menard58
#  Olives espagnoles à la pâte de poivrons                patchouliste
#
#                                            created_t      created_datetime  \
# product_name
#  Beeren schokoliert                       1471551023  2016-08-18T20:10:23Z
#  Biscuit Tablette Chocolat au Lait bio    1469265301  2016-07-23T09:15:01Z
#  Calamars à la Romaine surgelés           1398440321  2014-04-25T15:38:41Z
#  Crèmes brûlées à la vanille              1431259718  2015-05-10T12:08:38Z
#  Olives espagnoles à la pâte de poivrons  1425076106  2015-02-27T22:28:26Z
#
#                                          last_modified_t  \
# product_name
#  Beeren schokoliert                           1501427225
#  Biscuit Tablette Chocolat au Lait bio        1484589808
#  Calamars à la Romaine surgelés               1431600832
#  Crèmes brûlées à la vanille                  1459793603
#  Olives espagnoles à la pâte de poivrons      1487256859
#
#                                          last_modified_datetime    brands  \
# product_name
#  Beeren schokoliert                        2017-07-30T15:07:05Z  Alnatura
#  Biscuit Tablette Chocolat au Lait bio     2017-01-16T18:03:28Z   U Bio,U
#  Calamars à la Romaine surgelés            2015-05-14T10:53:52Z         U
#  Crèmes brûlées à la vanille               2016-04-04T18:13:23Z    Picard
#  Olives espagnoles à la pâte de poivrons   2017-02-16T14:54:19Z    migros
#
#                                                     countries  \
# product_name
#  Beeren schokoliert                       Germany,Switzerland
#  Biscuit Tablette Chocolat au Lait bio                 France
#  Calamars à la Romaine surgelés                        France
#  Crèmes brûlées à la vanille                           France
#  Olives espagnoles à la pâte de poivrons               Suisse
#
#                                                  countries_en  \
# product_name
#  Beeren schokoliert                       Germany,Switzerland
#  Biscuit Tablette Chocolat au Lait bio                 France
#  Calamars à la Romaine surgelés                        France
#  Crèmes brûlées à la vanille                           France
#  Olives espagnoles à la pâte de poivrons          Switzerland
#
#                                                                            ingredients_text  \
# product_name
#  Beeren schokoliert                       weiße Joghurtschokolade 60%, (Kakaobutter, Roh...
#  Biscuit Tablette Chocolat au Lait bio    Chocolat au lait 48% (sucre de canne, beurre d...
#  Calamars à la Romaine surgelés           Anneaux d'encornets (Illex argentinus ou Illex...
#  Crèmes brûlées à la vanille              Crème fraîche liquide (_lait_), eau, sucre liq...
#  Olives espagnoles à la pâte de poivrons  Olives 74%, pâte de poivrons 20% (pulpe de poi...
#
#                                          serving_size  additives_n  \
# product_name
#  Beeren schokoliert                             100 g          1.0
#  Biscuit Tablette Chocolat au Lait bio           25 g          3.0
#  Calamars à la Romaine surgelés                  125g          8.0
#  Crèmes brûlées à la vanille                    120 g          1.0
#  Olives espagnoles à la pâte de poivrons          30g          4.0
#
#                                                                                   additives  \
# product_name
#  Beeren schokoliert                        [ weisse-joghurtschokolade-60 -> de:weisse-jo...
#  Biscuit Tablette Chocolat au Lait bio     [ chocolat-au-lait-48 -> fr:chocolat-au-lait-...
#  Calamars à la Romaine surgelés            [ anneaux-d-encornets -> fr:anneaux-d-encorne...
#  Crèmes brûlées à la vanille               [ creme-fraiche-liquide -> fr:creme-fraiche-l...
#  Olives espagnoles à la pâte de poivrons   [ olives-74 -> fr:olives-74  ]  [ olives -> f...
#
#                                                                                additives_en  \
# product_name
#  Beeren schokoliert                                                       E414 - Acacia gum
#  Biscuit Tablette Chocolat au Lait bio    E336 - Potassium tartrates,E500 - Sodium carbo...
#  Calamars à la Romaine surgelés           E101 - Riboflavin,E330 - Citric acid,E412 - Gu...
#  Crèmes brûlées à la vanille                                             E407 - Carrageenan
#  Olives espagnoles à la pâte de poivrons  E202 - Potassium sorbate,E270 - Lactic acid,E4...
#
#                                           ingredients_from_palm_oil_n  \
# product_name
#  Beeren schokoliert                                               0.0
#  Biscuit Tablette Chocolat au Lait bio                            0.0
#  Calamars à la Romaine surgelés                                   0.0
#  Crèmes brûlées à la vanille                                      0.0
#  Olives espagnoles à la pâte de poivrons                          0.0
#
#                                           ingredients_that_may_be_from_palm_oil_n  \
# product_name
#  Beeren schokoliert                                                           0.0
#  Biscuit Tablette Chocolat au Lait bio                                        0.0
#  Calamars à la Romaine surgelés                                               0.0
#  Crèmes brûlées à la vanille                                                  0.0
#  Olives espagnoles à la pâte de poivrons                                      0.0
#
#                                          nutrition_grade_fr  energy_100g  \
# product_name
#  Beeren schokoliert                                       e       2296.0
#  Biscuit Tablette Chocolat au Lait bio                    e       2198.0
#  Calamars à la Romaine surgelés                           c        707.0
#  Crèmes brûlées à la vanille                              d       1286.0
#  Olives espagnoles à la pâte de poivrons                  c        601.0
#
#                                           fat_100g  saturated-fat_100g  \
# product_name
#  Beeren schokoliert                           36.5                22.9
#  Biscuit Tablette Chocolat au Lait bio        27.2                13.3
#  Calamars à la Romaine surgelés                6.8                 1.4
#  Crèmes brûlées à la vanille                  23.7                16.2
#  Olives espagnoles à la pâte de poivrons      15.0                 3.0
#
#                                           carbohydrates_100g  sugars_100g  \
# product_name
#  Beeren schokoliert                                     45.6         45.3
#  Biscuit Tablette Chocolat au Lait bio                  62.0         35.2
#  Calamars à la Romaine surgelés                         18.7          1.7
#  Crèmes brûlées à la vanille                            21.9         15.7
#  Olives espagnoles à la pâte de poivrons                 0.5          0.0
#
#                                           fiber_100g  proteins_100g  \
# product_name
#  Beeren schokoliert                              3.6            8.3
#  Biscuit Tablette Chocolat au Lait bio           2.3            7.0
#  Calamars à la Romaine surgelés                  1.2            7.5
#  Crèmes brûlées à la vanille                     2.0            2.3
#  Olives espagnoles à la pâte de poivrons         2.5            1.0
#
#                                           salt_100g  sodium_100g  \
# product_name
#  Beeren schokoliert                          0.3000     0.118110
#  Biscuit Tablette Chocolat au Lait bio       0.5300     0.208661
#  Calamars à la Romaine surgelés              1.2446     0.490000
#  Crèmes brûlées à la vanille                 0.1100     0.043307
#  Olives espagnoles à la pâte de poivrons     3.8000     1.496063
#
#                                           nutrition-score-fr_100g  \
# product_name
#  Beeren schokoliert                                          22.0
#  Biscuit Tablette Chocolat au Lait bio                       22.0
#  Calamars à la Romaine surgelés                               3.0
#  Crèmes brûlées à la vanille                                 14.0
#  Olives espagnoles à la pâte de poivrons                     10.0
#
#                                           nutrition-score-uk_100g
# product_name
#  Beeren schokoliert                                          22.0
#  Biscuit Tablette Chocolat au Lait bio                       22.0
#  Calamars à la Romaine surgelés                               3.0
#  Crèmes brûlées à la vanille                                 14.0
#  Olives espagnoles à la pâte de poivrons                     10.0

# %%
# 1 . nutrient breakdown

df = compute_nutrient_breakdown_ratio(df_food_study, col_macro_nutrients, df_reference_value)

# %%
# restricts to a sample of size 1000 

df = df.sample(1000)

# %%
plot_nutrient_breakdown_ratio(df, macro_nutrients)

# %%
# 2 . repartition score

df = compute_repartition_score(df_food_study, col_macro_nutrients, df_reference_value)

# %%
# restricts to a sample of size 30 

df = df.iloc[0:30,]

# %%
plot_nutrient_repartition_score(df)

# %% [markdown]
# ETUDE C :  Analyze ingredient's frequency
#
# sub functions

# %% [markdown]
# return a series of ingredients of randomly aliment retrieve from df_food_study

# %%
def get_aliment_ingredients(df_food_study):

    aliment = df_food_study.sample(1)
        
    ingredients = aliment.ingredients_text.str.replace(r'[-|_|(|)|.|,|*|%|#|:|\'\]\[]','')
    ingredients = ingredients.str.split()
    ingredients = ingredients.get_values()[0]
    ser_ingredients = pd.Series(ingredients)
    
    return (aliment, ser_ingredients)

# %% [markdown]
# retrieve a sample of aliments from df_food_study;
# based on this sample, a dictionnary of ingredients with columns (ingredient_name, occurrences),
# will be build
#
# în this dictionnary, ingredients will be sorted by 'occurences' and the shape will be limited to
# ingredient_count
#
# return a df containing a dictionnary of ingredients

# %%
def build_aliment_ingredient_dictionnary(df_food_study, sample_size:int, ingredient_count:int):

    dict_ingredients = {}
    f_build_ingredient_dictionary = utilities.build_word_dictionary(dict_ingredients)

    for i in np.arange(sample_size):
        ser_ingredients = get_aliment_ingredients(df_food_study)[1]
        f_build_ingredient_dictionary(ser_ingredients.to_json())

    df_dict = pd.DataFrame()
    df_dict = df_dict.from_dict(dict_ingredients, orient="index", columns=['occurences'])
    df_dict.sort_values('occurences', ascending=False, inplace=True)
    df_dict = df_dict.iloc[0:ingredient_count,]

    return df_dict

# %% [markdown]
# translate all entry of the df_dict index in a column called 'ingredient_en' and set
# the index on this one
#
# return a df with added columns 'ingredient_en'

# %%
def clean_word_dictionnary(df_dict):

    words_to_exclude = pd.Series(['A','THE','FROM', 'AND', 'OR','AND/OR', 'DE', 'ET', 'IN', 'OF', 
                                  'TO','AT', '&', 'PASTEURIZED', 'ENRICHED', 'MODIFIED',
                                  'CONTAINS', 'MALTED', 'LESS'])

    f_translate = utilities.translate_word()
    df_dict['ingredient_en'] = df_dict.index.to_series().apply(f_translate)

    df_dict.reset_index(inplace=True)
    df_dict.set_index('ingredient_en', inplace=True)
    df_dict.drop(words_to_exclude, errors="ignore", inplace=True)

    return df_dict

# %% [markdown]
# ETUDE C : main functions
#
# Analyze ingredient's frequency of ingredients used in aliments of df_food_study

# %%
def analyze_ingredients_frequency():

    df_food_study = helper_load_df_from_db("df_food_study_1", "df_food_study_2")
    df_food_study.set_index(['product_name'], inplace=True)

    aliment_sample_size = 1000
    ingredient_sample_size = 100
 
    df_dict = build_aliment_ingredient_dictionnary(df_food_study, 
                                                   aliment_sample_size, 
                                                   ingredient_sample_size)

    df_dict = clean_word_dictionnary(df_dict)
    df_dict.sort_values('occurences', ascending=False, inplace=True)
    
    df_dict = df_dict.iloc[0:30,] 
 
    fig, ax = plt.subplots()
    y_pos = np.arange(len(df_dict))
    ax.barh(y_pos, df_dict.occurences, align='center', color='green')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(df_dict.index)
    ax.invert_yaxis() 
    ax.set_xlabel("Occurrences")
    ax.set_title("The 30 most common ingredients founded in " + 
                 str(aliment_sample_size) + " aliments")

    plt.show()

# %%
analyze_ingredients_frequency()

# %% [markdown]
# ETUDE E : DATABASE
#
# sub functions

# %% [markdown]
# prepare normalized data
#
# build a dictionnary of ingredients
# for 1000 aliments randomly selected from df_food_study_2, extract its ingredients
# and join them with those in dictionnary
#
# one table with aliment and one table with only product_name and ingredient_name
# will be built

# %%
def prepare_normalization():
    
    df_food_study = helper_load_df_from_db("df_food_study_1", "df_food_study_2")

    df_all_aliment = pd.DataFrame()
    df_all_aliment_ingredient = pd.DataFrame()

    df_global_dict = build_aliment_ingredient_dictionnary(df_food_study, 1000, 100)
    df_global_dict = clean_word_dictionnary(df_global_dict)

    dict_aliment_ingredient = {}
    f_build_ingredient_dictionary = utilities.build_word_dictionary(dict_aliment_ingredient)
    
    for i in np.arange(1000):
        (df_aliment, ser_ingredients) = get_aliment_ingredients(df_food_study)
        f_build_ingredient_dictionary(ser_ingredients.to_json())
        
        df_aliment_ingredient = pd.DataFrame().from_dict(dict_aliment_ingredient, orient="index", columns=['occurences'])
    
        i_ingredients_in_dict = df_aliment_ingredient.index.intersection(df_global_dict.index)
        i_ingredients_in_dict = i_ingredients_in_dict.drop_duplicates()

        df = pd.DataFrame(index=i_ingredients_in_dict, columns=['product_name'])
        df = df.fillna(str(df_aliment.product_name.values.item(0)))
        df = df.reset_index()
        df.columns = ['ingredient_name', 'product_name']
         
        df_all_aliment_ingredient = pd.concat([df_all_aliment_ingredient, df])
        df_all_aliment = pd.concat([df_all_aliment, df_aliment])

        dict_aliment_ingredient.clear()

    return (df_all_aliment, df_all_aliment_ingredient)

# %% [markdown]
# save normalized df to database df_food.db

# %%
def build_normalized_database():

    (df_all_aliment, df_all_aliment_ingredient) = prepare_normalization()

    helper_store_df_to_db(df_all_aliment, 'df_food', 'aliment')
    helper_store_df_to_db(df_all_aliment_ingredient, 'df_food', 'aliment_ingredient')

    # set a primary key on table aliment
    
    db_file = PureWindowsPath(data_dir.joinpath('df_food.db'))
    db = sqlite3.connect(db_file.as_posix())
    c  = db.cursor()

    # SQLLITE doesn't support ALTER ADD / DROP 
    # c.execute("ALTER TABLE ALIMENT ADD PRIMARY KEY (product_name)")

    # retrieve ddl, modify it and replay

# %% [markdown]
# test database queries on df_food.db
#
# query all aliments which contains SALT

# %%
def perform_database_queries():

    build_normalized_database()

    db_file = PureWindowsPath(data_dir.joinpath('df_food.db'))
    db = sqlite3.connect(db_file.as_posix())

    # query all aliments which contains SALT
    df_q = pd.read_sql_query("select distinct(a.product_name) from aliment as a, aliment_ingredient as ai where ai.product_name = " +
                             " a.product_name and ai.ingredient_name = 'SALT'", con=db)

    return df_q

# %%
perform_database_queries()
# Out:
#                                           product_name
# 0                     Milkwise, Milk Beverage, Vanilla
# 1           Kettle Cooked Potato Chips, Honey Barbeque
# 2                      Sandwich Slices, White American
# 3              Fruitfetti Gourmet Popcorn, Green Apple
# 4                        Right Wheat Whole Grain Bread
# 5                         Gluten free chex granola mix
# 6                                      Melon Mix Taffy
# 7                                         Guava Butter
# 8      Turtles, Caramel Nut Clusters, Sea Salt Caramel
# 9                       Spinach Stuffed Rigatoni Pasta
# 10                  Rp's Pasta Company, Lasagna Sheets
# 11    Potato Skins Stuffed With Bacon & Cheddar Cheese
# 12                                    Ooey Gooey Rolls
# 13                                    Kipferl Biscuits
# 14                                  Beef & Pork Sticks
# 15        Calhoun Bend Mill, Awesome Onion Coating Mix
# 16                                   Seafood Primavera
# 17                       Sharp Cheddar, Fancy Shredded
# 18                   Cracker Crisps, Pumpkin Cranberry
# 19                                   Seasoned Croutons
# 20                           Cottage Cheese But Better
# 21   Classic Chinese Chicken Salad With Ginger Soy ...
# 22                                    Jewish Rye Bread
# 23                         Sweet Style Spaghetti Sauce
# 24                                Mozzarella Ciliegine
# 25       Frozen Custard, Oregon Marionberry Cheesecake
# 26                 Oikos, Greek Yogurt, Salted Caramel
# 27                    Clusters, Gourmet Pretzel Treats
# 28                  Milk Chocolate Bar, Salted Caramel
# 29                Pancake & Waffle Mix, Banana Caramel
# ..                                                 ...
# 524                                   Dried Cured Pork
# 525               Pork Smoked Sausage, Apple And Gouda
# 526                            Cranberry Nut Trail Mix
# 527                                         Kit Caesar
# 528                     Diced Tomatoes, Garlic & Onion
# 529                  Sicilian Inspired Chicken Sausage
# 530  Market Essentials, Honey & Oat Mixers With Alm...
# 531          Uncured Beef Hot Dogs With Cheddar Cheese
# 532          Good Morning Sunshine Spicy Ground Turkey
# 533                         Bratwurst Cocktail Smokies
# 534                        Hummous, Pineapple Jalapeno
# 535             Earth Grains, Whole Wheat Bakery Bread
# 536           Instant Pudding, Chocolate Peanut Butter
# 537                                 Black Tiger Shrimp
# 538      American Farmer, Popped Corn, Crunchy Caramel
# 539                     Valentine Mini Frosted Cookies
# 540  Oat Blenders, Lightly Sweetened Corn & Whole W...
# 541                                      Pork Parmesan
# 542                              Relish, Garlic Medium
# 543              Whole Grain Wheat Cereal, Raisin Bran
# 544                                       Hoop Cheddar
# 545  Dolcetto Gourmet Cookies, Cream Filled Rolled ...
# 546           Country Ranch Dressing & Dip, Buttermilk
# 547          Coffee Treats, Roman Egg Biscuits Cookies
# 548       The Original Chicago Style Giardiniera, Mild
# 549               1% Low Fat Chocolate Milk, Chocolate
# 550                                          On-The-Go
# 551  Lightlife, Smart Deli, Meatless Veggie Ham Slices
# 552            Organic Signature Butternut Squash Soup
# 553                       Red Beans And Rice, Original
#
# [554 rows x 1 columns]

# %% [markdown]
# ETUDE F : CORRELATION
#
# sub fonctions

# %% [markdown]
# check wether positive or negative relation between grade and score
# given grade a the better and e the worst

# %%
def determine_score_grade_relation():

    grade_convertion  = {'a':'1', 'b' : '2', 'c' : '3','d' : '4', 'e' : '5'}

    df_food_study = helper_load_df_from_db("df_food_study_1", "df_food_study_2")

    df = df_food_study.loc[:,['nutrition_grade_fr', 'nutrition-score-fr_100g']]
    
    df.nutrition_grade_fr = df.nutrition_grade_fr.apply(lambda x : grade_convertion.get(x))
    df = df.astype(float)    
    
    sns.pairplot(df, 
                 x_vars=['nutrition_grade_fr'],
                 y_vars=['nutrition-score-fr_100g'], 
                 kind="reg",
                 plot_kws={'line_kws':{'color':'red'}})
    plt.show()

# %%
def analyze_correlations(): 

    score_col = 'nutrition-score-fr_100g'
    cols_to_drop = set(['code', 'additives_n', 'ingredients_from_palm_oil_n', 'ingredients_that_may_be_from_palm_oil_n'])
    cols_to_drop.add(score_col)
    
    df_food_study = helper_load_df_from_db("df_food_study_1", "df_food_study_2")
    df_food_study = helper_load_df_from_db("df_food_study_1", "df_food_study_2")
    df_food_study.set_index(['product_name'], inplace=True)

    # retains only float columns
    num_cols = utilities.select_columns(df_food_study, float)
    
    # eliminates all colums define above
    predictors_cols = set(num_cols).difference(cols_to_drop)

    # sample of size 1000 is significant enough
    df = df_food_study.sample(1000)
     
    df_corr = df.corr()
    df_corr = df_corr.sort_values(by=score_col, ascending = False)
    
    sns.pairplot(df, 
                 x_vars=predictors_cols,
                 y_vars=[score_col], 
                 kind="reg",
                 plot_kws={'line_kws':{'color':'red'}})
    plt.show()
    
    df = df_corr[score_col]
    df.dropna(inplace=True)
   
    return df

# %%
determine_score_grade_relation()

# %%
analyze_correlations()
# Out:
# nutrition-score-fr_100g    1.000000
# nutrition-score-uk_100g    0.996082
# saturated-fat_100g         0.737314
# energy_100g                0.720266
# fat_100g                   0.691629
# sugars_100g                0.557967
# carbohydrates_100g         0.380145
# salt_100g                  0.247087
# sodium_100g                0.247085
# proteins_100g              0.057948
# additives_n                0.046118
# index                     -0.039612
# code                      -0.052940
# fiber_100g                -0.118851
# Name: nutrition-score-fr_100g, dtype: float64

# %% [markdown]
# Constatations :
#
# Nutrition grade and score are positively correlated (see determine_score_grade_relation).
# Thus from the above correlations we conclude that fat tend to have a negative impact (they increase the final score) while fiber tend to contribute to the opposite.

# %% [markdown]
# ETUDE D : TIMESERIES
#
# sub fonctions

# %%
def compute_mean_elapsed(df_food_study):

    ser_create = pd.to_datetime(df_food_study.created_datetime)
    ser_modify = pd.to_datetime(df_food_study.last_modified_datetime)

    # verify that no null values in both series
    if(ser_create.isnull().sum() == 0 and ser_modify.isnull().sum() == 0):

        # compute difference
        ser_delta = ser_modify - ser_create

        # verify that no negative values in the difference
        if(ser_delta.where(lambda x : x < pd.Timedelta(0)).count() == 0):
            mean_delta = ser_delta.mean()

    return mean_delta

# %% [markdown]
# plot created entries per years / month

# %%
def plot_years_month_entries(df_food_study):

    month = calendar.month_name[1:]

    ser_create = pd.to_datetime(df_food_study.created_datetime)
    df = pd.DataFrame(ser_create, columns = ['created_datetime', 'year', 'month'])

    df.set_index('created_datetime', inplace=True)
    df.year = df.index.year
    df.month = df.index.month

    df.reset_index(inplace=True)
    df.set_index(['year', 'month'], inplace=True)

    df_g = np.log(df.groupby(['year', 'month']).count())
    
    # define plot parameters
    ax = df_g.unstack(level=0).plot.bar(width=0.8)
    x_pos = np.arange(len(month))
    ax.set_xticks(x_pos)
    ax.set_xticklabels(month, rotation=45)
    ax.set_ylabel("number of created aliment's entries")

    ax.set_xlabel("Months")
    ax.set_title("(logarithm of) number of created aliment's entries in the database")
    ax.legend(labels=df_g.index.levels[0])

    plt.show()

# %% [markdown]
# plot mean created entries per month over the timeline

# %%
def plot_mean_month_entries(df_food_study):

    month = calendar.month_name[1:]

    ser_create = pd.to_datetime(df_food_study.created_datetime)
    df = pd.DataFrame(ser_create, columns = ['created_datetime', 'year', 'month'])

    df.set_index('created_datetime', inplace=True)
    df.year = df.index.year
    df.month = df.index.month

    df.reset_index(inplace=True)
    df.set_index(['year', 'month'], inplace=True)

    df_g = np.log(df.groupby(['month','year']).count())
    mean = df_g.groupby('month').mean()
    std = df_g.groupby('month').std()
    
    # define plot parameters
    fig, ax = plt.subplots()
    x_pos = np.arange(len(month))
    ax.bar(x_pos, mean['created_datetime'], align='center', 
           color='blue', yerr=std['created_datetime'], ecolor='black')

    ax.set_xticks(x_pos)
    ax.set_xticklabels(month, rotation=45)
    ax.set_ylabel("mean of created aliment's entries")

    ax.set_xlabel("Months")
    ax.set_title("(logarithm of) mean of created aliment's entries in the database")
  
    plt.show()

# %% [markdown]
# ETUDE D : main function

# %%
def analyze_time_series():

    df_food_study = helper_load_df_from_db("df_food_study_1", "df_food_study_2")

    print("mean elapsed time between created time and last update time")
    print(compute_mean_elapsed(df_food_study))

    plot_mean_month_entries(df_food_study)
    plot_years_month_entries(df_food_study)

# %%
analyze_time_series()
# Out:
# mean elapsed time between created time and last update time
# 62 days 23:24:51.999538

# %% [markdown]
# We take the logarithm in oder to minimize the sie of created entries in 2017.
